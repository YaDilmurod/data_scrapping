# %%
import requests
import pandas as pd
from datetime import datetime

# %%
category_mapping = {
    7: "Квартира",
    8: "Дом",
    10: "Для бизнеса",
    11: "Земельный участок"
}

state_mapping = {
    False: "Новострой",
    True: "Вторичка",
}

def get_json_data(api_url):
    response = requests.get(api_url)
    if response.status_code == 200:
        return response.json()
    else:
        print(f"Error {response.status_code}: Unable to fetch data from {api_url}")
        return None

def create_dataframe(json_data):
    if json_data and 'results' in json_data:
        results = json_data['results']
        if not results:
            print("No results found. Skipping to the next iteration.")
            return pd.DataFrame()

        apartments = []
        for result in results:
            apartment = {
                "id": result.get("id"),
                "categoryId": category_mapping.get(result.get("categoryId")),
                "description": result.get("description"),
                "price": result.get("price"),
                "priceCurrency": result.get("priceCurrency"),
                "address": result.get("address"),
                "region": result["region"]["name"]["en"] if result.get("region") else None,
                "district": result["district"]["name"]["en"] if result.get("district") else None,
                "street": result["street"]["name"]["en"] if result.get("street") else None,
                "zone": result["zone"]["name"]["en"] if result.get("zone") else None,
                "room": result.get("room"),
                "square": result.get("square"),
                "floor": result.get("floor"),
                "floorTotal": result.get("floorTotal"),
                "isNewBuilding": state_mapping.get(result.get("isNewBuilding")),
                "repair": result.get("repair"),
                "foundation": result.get("foundation"),
                "residentialComplex": result["residentialComplex"]["name"]["en"] if result.get("residentialComplex") else None,
                "lat": result.get("lat"),
                "lng": result.get("lng"),
                "createdAt": result.get("createdAt"),
                "updatedAt": result.get("updatedAt"),
                "isUrgently": result.get("isUrgently"),
                "isVip": result.get("isVip"),
                "isPremium": result.get("isPremium"),
                "isFavorite": result.get("isFavorite"),
                "views": result.get("views"),
                "clicks": result.get("clicks"),
                "favorites": result.get("favorites")
            }
            apartments.append(apartment)
        return pd.DataFrame(apartments)
    else:
        print("Invalid JSON data. Skipping to the next iteration.")
        return pd.DataFrame()

def fetch_data(start_page, end_page):
    all_data = []

    for page_number in range(start_page, end_page):
       
        # Construct the API URL for the current page number and page
        api_url = f"{url_template}{page_number}"

        print(api_url)
        # Fetch JSON data
        json_data = get_json_data(api_url)

        # Check if the response is empty or results are empty
        if not json_data or not json_data.get('results'):
            print(f"No results for page={page_number}. Exiting the loop.")
            break

        # Create DataFrame
        df = create_dataframe(json_data)

        # Append DataFrame to the list
        all_data.append(df)
    
    # Concatenate all DataFrames into a single DataFrame
    final_df = pd.concat(all_data, ignore_index=True)
    return final_df

# Example for room__in=1
url_template = "https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page="

start_page = 1
end_page = 400

final_df = fetch_data(start_page, end_page)
# Out:
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=1
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=2
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=3
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=4
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=5
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=6
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=7
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=8
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=9
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=10
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=11
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=12
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=13
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=14
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=15
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=16
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=17
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=18
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=19
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=20
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=21
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=22
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=23
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=24
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=25
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=26
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=27
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=28
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=29
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=30
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=31
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=32
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=33
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=34
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=35
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=36
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=37
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=38
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=39
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=40
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=41
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=42
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=43
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=44
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=45
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=46
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=47
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=48
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=49
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=50
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=51
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=52
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=53
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=54
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=55
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=56
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=57
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=58
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=59
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=60
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=61
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=62
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=63
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=64
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=65
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=66
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=67
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=68
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=69
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=70
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=71
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=72
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=73
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=74
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=75
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=76
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=77
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=78
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=79
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=80
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=81
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=82
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=83
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=84
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=85
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=86
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=87
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=88
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=89
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=90
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=91
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=92
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=93
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=94
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=95
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=96
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=97
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=98
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=99
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=100
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=101
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=102
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=103
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=104
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=105
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=106
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=107
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=108
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=109
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=110
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=111
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=112
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=113
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=114
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=115
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=116
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=117
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=118
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=119
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=120
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=121
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=122
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=123
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=124
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=125
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=126
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=127
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=128
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=129
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=130
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=131
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=132
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=133
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=134
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=135
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=136
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=137
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=138
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=139
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=140
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=141
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=142
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=143
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=144
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=145
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=146
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=147
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=148
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=149
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=150
# ...
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=241
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=242
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=243
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=244
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=245
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=246
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=247
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=248
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=249
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=250
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=251
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=252
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=253
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=254
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=255
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=256
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=257
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=258
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=259
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=260
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=261
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=262
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=263
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=264
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=265
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=266
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=267
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=268
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=269
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=270
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=271
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=272
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=273
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=274
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=275
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=276
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=277
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=278
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=279
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=280
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=281
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=282
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=283
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=284
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=285
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=286
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=287
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=288
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=289
# https://api.uybor.uz/api/v1/listings?mode=search&includeFeatured=true&limit=20&embed=category%2CsubCategory%2CresidentialComplex%2Cregion%2Ccity%2Cdistrict%2Czone%2Cstreet%2Cmetro%2Cmedia%2Cuser%2Cuser.avatar%2Cuser.organization%2Cuser.organization.logo&order=upAt&operationType__eq=sale&priceCurrency__eq=usd&page=290
# No results for page=290. Exiting the loop.

# %%
final_df = final_df.drop(["id", 'isVip', 'isPremium', 'isFavorite', 'views', 'clicks', 'favorites', 'street', 'zone', 'residentialComplex'], axis=1)
final_df = final_df.rename(columns={"floor": "Этаж", "floorTotal": "Этажность", "repair": "Ремонт",
                                    "foundation": "Материал", 'room': "Количество комнат", "square": "Площадь", 'region': 'Регион',
                                    'description': 'Название', 'price': 'Цена', 'priceCurrency': 'Валюта',
                                    'district': "Район", 'address': 'Адрес', 'isNewBuilding': 'Новое здание',
                                    'isUrgently': 'Срочно', "createdAt": "Дата публикации", "updatedAt": "Обновлён",
                                    "lat": "Широта", "lng": "Долгота", "categoryId": "Тип", "isNewBuilding": "Тип постройки"})

final_df['Дата публикации'] = pd.to_datetime(final_df['Дата публикации'], utc=True)
final_df['Обновлён'] = pd.to_datetime(final_df['Обновлён'], utc=True)
final_df['Валюта'] = final_df['Валюта'].str.upper()
repair_mapping = {
    'evro': 'Евроремонт',
    'chernovaya': 'Черновая отделка',
    'custom': 'Индивидуальный',
    'kapital': 'Капитальный',
    'sredniy': 'Средний',
    None: None  # Keep None values unchanged
}
material_mapping = {
    'kirpich': 'Кирпич',
    'monolit': 'Монолит',
    'panel': 'Панель',
    'other': 'Другой',
    None: None  # Keep None values unchanged
}
final_df['Ремонт'] = final_df['Ремонт'].replace(repair_mapping)
final_df['Материал'] = final_df['Материал'].replace(material_mapping)
final_df['Дата публикации'] = final_df['Дата публикации'].dt.strftime('%d.%m.%Y')
final_df['Обновлён'] = final_df['Обновлён'].dt.strftime('%d.%m.%Y')

# %%
columns_to_check = ["Источник", "Название", "Тип","Санузел", "Тип постройки", "Материал", "Широта", 
                    "Долгота", "Район", "Этаж", "Этажность", "Ремонт", "Площадь", 
                    "Количество комнат", "Дата публикации", "Валюта", "Цена", "Дата создания"]

# Create a new DataFrame with the specified columns
new_df = pd.DataFrame(columns=columns_to_check)

# Check if columns exist in final_df and create them with None values if not
for column in columns_to_check:
    if column not in final_df.columns:
        final_df[column] = None
        new_df[column] = None
    else:
        new_df[column] = final_df[column]

 
new_df["Источник"] = 'Uybor'
new_df["Район"] = ''
new_df["Дата создания"] = datetime.now().strftime("%d.%m.%Y")
new_df[columns_to_check]
# Out:
#      Источник                                           Название  \
# 0       Uybor  2я линия, идеальный вариант для офиса, развита...
# 1       Uybor  Toshkent shaxar. Sergeli tumani. Xonabod maxal...
# 2       Uybor  \n\nЗдравствуйте продаётся дом под слом 6.55 с...
# 3       Uybor  Чистенькая, уютная квартира, израильская входн...
# 4       Uybor  Продаётся 3/4/4 \nКирпич 77 серия\nЧиланзар ра...
# ...       ...                                                ...
# 7219    Uybor  Продается 3- комнатная квартира в центре город...
# 7220    Uybor  Евроремонт.Йул юзида жойлашган. Том 2контур ки...
# 7221    Uybor  квартира чистая. состояние отличное зайти жить...
# 7222    Uybor  Новостройка, евроремонт, никто не жил, можно п...
# 7223    Uybor  Продаётся своя 2х-комнатная квартира, передела...
#
#                     Тип Санузел Тип постройки Материал     Широта    Долгота  \
# 0           Для бизнеса    None          None   Кирпич  41.376934  69.278015
# 1                   Дом    None          None     blok  41.220840  69.208725
# 2     Земельный участок    None          None   Другой  41.334115  69.320960
# 3              Квартира    None     Новострой   Панель  41.334202  69.168091
# 4              Квартира    None     Новострой   Кирпич  41.281410  69.212669
# ...                 ...     ...           ...      ...        ...        ...
# 7219           Квартира    None     Новострой   Панель  41.305637  69.263313
# 7220           Квартира    None     Новострой  Монолит  41.371628  69.269943
# 7221           Квартира    None     Новострой   Кирпич  41.284649  69.228806
# 7222           Квартира    None      Вторичка   Кирпич  41.376934  69.278015
# 7223           Квартира    None     Новострой   Кирпич  41.327526  69.336723
#
#      Район  Этаж  Этажность          Ремонт  Площадь Количество комнат  \
# 0            1.0        9.0      Евроремонт     77.0              None
# 1            NaN        1.0         Средний    600.0                6+
# 2            NaN        NaN     Капитальный      NaN              None
# 3            3.0        5.0  Индивидуальный     66.0                 2
# 4            4.0        4.0      Евроремонт     70.0                 3
# ...    ...   ...        ...             ...      ...               ...
# 7219         9.0        9.0         Средний     73.0                 3
# 7220         4.0        4.0      Евроремонт     80.0                 4
# 7221         4.0        5.0  Индивидуальный     68.0                 3
# 7222         1.0        9.0      Евроремонт     77.0                 3
# 7223         4.0        5.0         Средний     54.0                 2
#
#      Дата публикации Валюта    Цена Дата создания
# 0         17.02.2024    USD  112000    02.06.2024
# 1         06.05.2024    USD  170000    02.06.2024
# 2         13.04.2024    USD  500000    02.06.2024
# 3         16.06.2023    USD   70000    02.06.2024
# 4         18.10.2023    USD   93000    02.06.2024
# ...              ...    ...     ...           ...
# 7219      18.04.2024    USD  110000    02.06.2024
# 7220      07.02.2024    USD   85000    02.06.2024
# 7221      18.04.2024    USD   82000    02.06.2024
# 7222      30.01.2024    USD  112000    02.06.2024
# 7223      08.05.2024    USD   75000    02.06.2024
#
# [7224 rows x 18 columns]

# %%
import pandas as pd
import os

# Assuming x is your variable and data is the data you want to store
name_of_file = "Uybor"
df = pd.DataFrame(new_df)

# Set the path to the Excels folder (assuming it is a sibling of the Notebooks folder)
excels_folder_path = os.path.join(os.path.dirname(os.getcwd()), "Excels")

# Check if the folder exists, if not, create it
if not os.path.exists(excels_folder_path):
    os.makedirs(excels_folder_path)

# Create a folder with the name_of_file only if it doesn't exist
file_folder_path = os.path.join(excels_folder_path, name_of_file)

if not os.path.exists(file_folder_path):
    os.makedirs(file_folder_path)

excel_file_name = os.path.join(file_folder_path, f"{name_of_file}.xlsx")

# Check if the file already exists
if os.path.exists(excel_file_name):
    # Read the existing Excel file into a DataFrame
    existing_df = pd.read_excel(excel_file_name)

    # Append the new data to the existing DataFrame
    updated_df = pd.concat([existing_df, df], ignore_index=True)

    # Check for duplicates in all columns
    duplicates_mask = updated_df.duplicated(keep=False)

    # Print the number of duplicates
    num_duplicates = duplicates_mask.sum()
    print(f"Number of duplicates after adding new data: {num_duplicates}")

    # If duplicates exist, remove them
    if any(duplicates_mask):
        updated_df = updated_df[~duplicates_mask]

    # Write the updated DataFrame back to the Excel file
    updated_df.to_excel(excel_file_name, index=False)

    print(f"Data added to existing Excel file '{excel_file_name}' after removing duplicates.")
else:
    # If the file doesn't exist, create a new Excel file with the data
    df.to_excel(excel_file_name, index=False)
    print(f"Excel file '{excel_file_name}' created with new data.")
# Out:
# Excel file '/Users/didi/Desktop/data_scrapping/Data Scrapping/Code/Excels/Uybor/Uybor.xlsx' created with new data.
