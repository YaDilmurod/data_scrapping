# %%
import requests
from bs4 import BeautifulSoup
from datetime import datetime
import pandas as pd
from requests.exceptions import ConnectTimeout

# %%
import requests
from bs4 import BeautifulSoup
from datetime import datetime
import pandas as pd

def extract_currency_and_value(column_value):
    parts = column_value.split(' у.е.')
    currency = 'None'
    price = 'None'

    if len(parts) >= 2:
        price = parts[-2].strip()
        currency = 'USD'

    return price, currency

def extract_date(date_element):
    date_str = date_element.text.strip()
    date_format = "%d.%m.%Y %H:%M:%S"
    date_obj = datetime.strptime(date_str, date_format)
    return date_obj

def scrape_dom_uz_detail(detail_url):
    result_entry = {}

    try:
        response = requests.get(detail_url)

        if response.status_code == 200:
            apartment_soup = BeautifulSoup(response.text, 'html.parser')

            # Extract the information from the detailed page
            title_element = apartment_soup.find('div', class_='page-title')  # Adjust the class based on the website structure
            date_element = apartment_soup.find('div', class_='date')

            if title_element and date_element:
                apartment_title = title_element.text.strip()
                apartment_date = extract_date(date_element)

                # Extract information from ul element with class table-block
                details_element = apartment_soup.find('ul', class_='table-block')
                details = {}

                if details_element:
                    for strong_tag, span_tag in zip(details_element.find_all('strong'), details_element.find_all('span')):
                        column_name = strong_tag.text.strip()[:-1]
                        column_value = span_tag.text.strip() if span_tag else 'None'

                        # Special handling for the "Цена" column
                        if column_name == 'Цена':
                            price, currency = extract_currency_and_value(column_value)
                            details['Валюта'] = currency
                            details['Цена'] = price
                        else:
                            details[column_name] = column_value

                # Extract latitude and longitude
                lon_input = apartment_soup.find('input', {'name': 'YMAP_POINT_LON'})
                lat_input = apartment_soup.find('input', {'name': 'YMAP_POINT_LAT'})
                longitude = lon_input['value'] if lon_input else 'None'
                latitude = lat_input['value'] if lat_input else 'None'
                details['Долгота'] = longitude
                details['Широта'] = latitude

                # Add the information to the result entry
                result_entry = {
                    'Название': apartment_title,
                    'Дата': apartment_date,
                    **details
                }

    except Exception as e:
        print(f"An exception occurred while scraping {detail_url}: {e}")

    return result_entry

def scrape_dom_uz_range(main_url, start_page, stop_page):
    results = []

    for page in range(start_page, stop_page + 1):
        detail_url = f"{main_url}detail/{page}"
        print(detail_url)
        result_entry = scrape_dom_uz_detail(detail_url)

        if result_entry:
            results.append(result_entry)

    # Create a DataFrame from the results list
    final_df = pd.DataFrame(results)

    return final_df

# Specify the range of page numbers you want to scrape
start_page_number = 13500
stop_page_number = start_page_number + 1000

main_url_dom_uz = "https://dom.uz/catalog/"
final_df = scrape_dom_uz_range(main_url_dom_uz, start_page_number, stop_page_number)
# Out:
# https://dom.uz/catalog/detail/13500
# https://dom.uz/catalog/detail/13501
# https://dom.uz/catalog/detail/13502
# https://dom.uz/catalog/detail/13503
# https://dom.uz/catalog/detail/13504
# https://dom.uz/catalog/detail/13505
# https://dom.uz/catalog/detail/13506
# https://dom.uz/catalog/detail/13507
# https://dom.uz/catalog/detail/13508
# https://dom.uz/catalog/detail/13509
# https://dom.uz/catalog/detail/13510
# https://dom.uz/catalog/detail/13511
# https://dom.uz/catalog/detail/13512
# https://dom.uz/catalog/detail/13513
# https://dom.uz/catalog/detail/13514
# https://dom.uz/catalog/detail/13515
# https://dom.uz/catalog/detail/13516
# https://dom.uz/catalog/detail/13517
# https://dom.uz/catalog/detail/14002
# https://dom.uz/catalog/detail/14003
# https://dom.uz/catalog/detail/14004
# https://dom.uz/catalog/detail/14005
# https://dom.uz/catalog/detail/14006
# https://dom.uz/catalog/detail/14007
# https://dom.uz/catalog/detail/14008
# https://dom.uz/catalog/detail/14009
# https://dom.uz/catalog/detail/14010
# https://dom.uz/catalog/detail/14011
# https://dom.uz/catalog/detail/14012
# https://dom.uz/catalog/detail/14013
# https://dom.uz/catalog/detail/14014
# https://dom.uz/catalog/detail/14015
# https://dom.uz/catalog/detail/14016
# https://dom.uz/catalog/detail/14017
# https://dom.uz/catalog/detail/14018
# https://dom.uz/catalog/detail/14019
# https://dom.uz/catalog/detail/14020
# https://dom.uz/catalog/detail/14021
# https://dom.uz/catalog/detail/14022
# https://dom.uz/catalog/detail/14023
# https://dom.uz/catalog/detail/14024
# https://dom.uz/catalog/detail/14025
# https://dom.uz/catalog/detail/14026
# https://dom.uz/catalog/detail/14027
# https://dom.uz/catalog/detail/14028
# https://dom.uz/catalog/detail/14029
# https://dom.uz/catalog/detail/14030
# https://dom.uz/catalog/detail/14031
# https://dom.uz/catalog/detail/14032
# https://dom.uz/catalog/detail/14033
# https://dom.uz/catalog/detail/14034
# https://dom.uz/catalog/detail/14035
# https://dom.uz/catalog/detail/14036
# https://dom.uz/catalog/detail/14037
# https://dom.uz/catalog/detail/14038
# https://dom.uz/catalog/detail/14039
# https://dom.uz/catalog/detail/14040
# https://dom.uz/catalog/detail/14041
# https://dom.uz/catalog/detail/14042
# https://dom.uz/catalog/detail/14043
# https://dom.uz/catalog/detail/14044
# https://dom.uz/catalog/detail/14045
# https://dom.uz/catalog/detail/14046
# https://dom.uz/catalog/detail/14047
# https://dom.uz/catalog/detail/14048
# https://dom.uz/catalog/detail/14049
# https://dom.uz/catalog/detail/14050
# https://dom.uz/catalog/detail/14051
# https://dom.uz/catalog/detail/14052
# https://dom.uz/catalog/detail/14053
# https://dom.uz/catalog/detail/14054
# https://dom.uz/catalog/detail/14055
# https://dom.uz/catalog/detail/14056
# https://dom.uz/catalog/detail/14057
# https://dom.uz/catalog/detail/14058
# https://dom.uz/catalog/detail/14059
# https://dom.uz/catalog/detail/14060
# https://dom.uz/catalog/detail/14061
# https://dom.uz/catalog/detail/14062
# https://dom.uz/catalog/detail/14063
# https://dom.uz/catalog/detail/14064
# https://dom.uz/catalog/detail/14065
# https://dom.uz/catalog/detail/14066
# https://dom.uz/catalog/detail/14067
# https://dom.uz/catalog/detail/14068
# https://dom.uz/catalog/detail/14069
# https://dom.uz/catalog/detail/14070
# https://dom.uz/catalog/detail/14071
# https://dom.uz/catalog/detail/14072
# https://dom.uz/catalog/detail/14073
# https://dom.uz/catalog/detail/14074
# https://dom.uz/catalog/detail/14075
# https://dom.uz/catalog/detail/14076
# https://dom.uz/catalog/detail/14077
# https://dom.uz/catalog/detail/14078
# https://dom.uz/catalog/detail/14079
# https://dom.uz/catalog/detail/14080
# https://dom.uz/catalog/detail/14081
# https://dom.uz/catalog/detail/14082
# https://dom.uz/catalog/detail/14244
# https://dom.uz/catalog/detail/14245
# https://dom.uz/catalog/detail/14246
# https://dom.uz/catalog/detail/14247
# https://dom.uz/catalog/detail/14248
# https://dom.uz/catalog/detail/14249
# https://dom.uz/catalog/detail/14250
# https://dom.uz/catalog/detail/14251
# https://dom.uz/catalog/detail/14252
# https://dom.uz/catalog/detail/14253
# https://dom.uz/catalog/detail/14254
# https://dom.uz/catalog/detail/14255
# https://dom.uz/catalog/detail/14256
# https://dom.uz/catalog/detail/14257
# https://dom.uz/catalog/detail/14258
# https://dom.uz/catalog/detail/14259
# https://dom.uz/catalog/detail/14260
# https://dom.uz/catalog/detail/14261
# https://dom.uz/catalog/detail/14262
# https://dom.uz/catalog/detail/14263
# https://dom.uz/catalog/detail/14264
# https://dom.uz/catalog/detail/14265
# https://dom.uz/catalog/detail/14266
# https://dom.uz/catalog/detail/14267
# https://dom.uz/catalog/detail/14268
# https://dom.uz/catalog/detail/14269
# https://dom.uz/catalog/detail/14270
# https://dom.uz/catalog/detail/14271
# https://dom.uz/catalog/detail/14272
# https://dom.uz/catalog/detail/14273
# https://dom.uz/catalog/detail/14274
# https://dom.uz/catalog/detail/14275
# https://dom.uz/catalog/detail/14276
# https://dom.uz/catalog/detail/14277
# https://dom.uz/catalog/detail/14278
# https://dom.uz/catalog/detail/14279
# https://dom.uz/catalog/detail/14280
# https://dom.uz/catalog/detail/14281
# https://dom.uz/catalog/detail/14282
# https://dom.uz/catalog/detail/14283
# https://dom.uz/catalog/detail/14284
# https://dom.uz/catalog/detail/14285
# https://dom.uz/catalog/detail/14286
# https://dom.uz/catalog/detail/14287
# https://dom.uz/catalog/detail/14288
# https://dom.uz/catalog/detail/14289
# https://dom.uz/catalog/detail/14290
# https://dom.uz/catalog/detail/14291
# https://dom.uz/catalog/detail/14292
# https://dom.uz/catalog/detail/14293
# https://dom.uz/catalog/detail/14294
# https://dom.uz/catalog/detail/14295
# https://dom.uz/catalog/detail/14296
# https://dom.uz/catalog/detail/14297
# https://dom.uz/catalog/detail/14298
# https://dom.uz/catalog/detail/14299
# https://dom.uz/catalog/detail/14300
# https://dom.uz/catalog/detail/14301
# https://dom.uz/catalog/detail/14302
# https://dom.uz/catalog/detail/14303
# https://dom.uz/catalog/detail/14304
# https://dom.uz/catalog/detail/14305
# https://dom.uz/catalog/detail/14306
# https://dom.uz/catalog/detail/14307
# https://dom.uz/catalog/detail/14308
# https://dom.uz/catalog/detail/14309
# https://dom.uz/catalog/detail/14310
# https://dom.uz/catalog/detail/14311
# https://dom.uz/catalog/detail/14312
# https://dom.uz/catalog/detail/14313
# https://dom.uz/catalog/detail/14314
# https://dom.uz/catalog/detail/14315
# https://dom.uz/catalog/detail/14316
# https://dom.uz/catalog/detail/14317
# https://dom.uz/catalog/detail/14318
# https://dom.uz/catalog/detail/14319
# https://dom.uz/catalog/detail/14320
# https://dom.uz/catalog/detail/14321
# https://dom.uz/catalog/detail/14322
# https://dom.uz/catalog/detail/14323
# https://dom.uz/catalog/detail/14324
# https://dom.uz/catalog/detail/14325
# https://dom.uz/catalog/detail/14326
# https://dom.uz/catalog/detail/14327
# https://dom.uz/catalog/detail/14328
# https://dom.uz/catalog/detail/14329
# https://dom.uz/catalog/detail/14330
# https://dom.uz/catalog/detail/14331
# https://dom.uz/catalog/detail/14332
# https://dom.uz/catalog/detail/14333
# https://dom.uz/catalog/detail/14334
# https://dom.uz/catalog/detail/14335
# https://dom.uz/catalog/detail/14336
# https://dom.uz/catalog/detail/14337
# https://dom.uz/catalog/detail/14338
# https://dom.uz/catalog/detail/14339
# https://dom.uz/catalog/detail/14340
# https://dom.uz/catalog/detail/14341
# https://dom.uz/catalog/detail/14342
# https://dom.uz/catalog/detail/14343
# https://dom.uz/catalog/detail/14344
# https://dom.uz/catalog/detail/14345
# https://dom.uz/catalog/detail/14346
# https://dom.uz/catalog/detail/14347
# https://dom.uz/catalog/detail/14348
# https://dom.uz/catalog/detail/14349
# https://dom.uz/catalog/detail/14350
# https://dom.uz/catalog/detail/14351
# https://dom.uz/catalog/detail/14352
# https://dom.uz/catalog/detail/14353
# https://dom.uz/catalog/detail/14354
# https://dom.uz/catalog/detail/14355
# https://dom.uz/catalog/detail/14356
# https://dom.uz/catalog/detail/14357
# https://dom.uz/catalog/detail/14358
# https://dom.uz/catalog/detail/14359
# https://dom.uz/catalog/detail/14360
# https://dom.uz/catalog/detail/14361
# https://dom.uz/catalog/detail/14362
# https://dom.uz/catalog/detail/14363
# https://dom.uz/catalog/detail/14364
# https://dom.uz/catalog/detail/14365
# https://dom.uz/catalog/detail/14366
# https://dom.uz/catalog/detail/14367
# https://dom.uz/catalog/detail/14368
# https://dom.uz/catalog/detail/14369
# https://dom.uz/catalog/detail/14370
# https://dom.uz/catalog/detail/14371
# https://dom.uz/catalog/detail/14372
# https://dom.uz/catalog/detail/14373
# https://dom.uz/catalog/detail/14374
# https://dom.uz/catalog/detail/14375
# https://dom.uz/catalog/detail/14376
# https://dom.uz/catalog/detail/14377
# https://dom.uz/catalog/detail/14378
# https://dom.uz/catalog/detail/14379
# https://dom.uz/catalog/detail/14380
# https://dom.uz/catalog/detail/14381
# https://dom.uz/catalog/detail/14382
# https://dom.uz/catalog/detail/14383
# https://dom.uz/catalog/detail/14384
# https://dom.uz/catalog/detail/14385
# https://dom.uz/catalog/detail/14386
# https://dom.uz/catalog/detail/14387
# https://dom.uz/catalog/detail/14388
# https://dom.uz/catalog/detail/14389
# https://dom.uz/catalog/detail/14390
# https://dom.uz/catalog/detail/14391
# https://dom.uz/catalog/detail/14392
# https://dom.uz/catalog/detail/14393
# https://dom.uz/catalog/detail/14394
# https://dom.uz/catalog/detail/14395
# https://dom.uz/catalog/detail/14396
# https://dom.uz/catalog/detail/14397
# https://dom.uz/catalog/detail/14398
# https://dom.uz/catalog/detail/14399
# https://dom.uz/catalog/detail/14400
# https://dom.uz/catalog/detail/14401
# https://dom.uz/catalog/detail/14402
# https://dom.uz/catalog/detail/14403
# https://dom.uz/catalog/detail/14404
# https://dom.uz/catalog/detail/14405
# https://dom.uz/catalog/detail/14406
# https://dom.uz/catalog/detail/14407
# https://dom.uz/catalog/detail/14408
# https://dom.uz/catalog/detail/14409
# https://dom.uz/catalog/detail/14410
# https://dom.uz/catalog/detail/14411
# https://dom.uz/catalog/detail/14412
# https://dom.uz/catalog/detail/14413
# https://dom.uz/catalog/detail/14414
# https://dom.uz/catalog/detail/14415
# https://dom.uz/catalog/detail/14416
# https://dom.uz/catalog/detail/14417
# https://dom.uz/catalog/detail/14418
# https://dom.uz/catalog/detail/14419
# https://dom.uz/catalog/detail/14420
# https://dom.uz/catalog/detail/14421
# https://dom.uz/catalog/detail/14422
# https://dom.uz/catalog/detail/14423
# https://dom.uz/catalog/detail/14424
# https://dom.uz/catalog/detail/14425
# https://dom.uz/catalog/detail/14426
# https://dom.uz/catalog/detail/14427
# https://dom.uz/catalog/detail/14428
# https://dom.uz/catalog/detail/14429
# https://dom.uz/catalog/detail/14430
# https://dom.uz/catalog/detail/14431
# https://dom.uz/catalog/detail/14432
# https://dom.uz/catalog/detail/14433
# https://dom.uz/catalog/detail/14434
# https://dom.uz/catalog/detail/14435
# https://dom.uz/catalog/detail/14436
# https://dom.uz/catalog/detail/14437
# https://dom.uz/catalog/detail/14438
# https://dom.uz/catalog/detail/14439
# https://dom.uz/catalog/detail/14440
# https://dom.uz/catalog/detail/14441
# https://dom.uz/catalog/detail/14442
# https://dom.uz/catalog/detail/14443
# https://dom.uz/catalog/detail/14444
# https://dom.uz/catalog/detail/14445
# https://dom.uz/catalog/detail/14446
# https://dom.uz/catalog/detail/14447
# https://dom.uz/catalog/detail/14448
# https://dom.uz/catalog/detail/14449
# https://dom.uz/catalog/detail/14450
# https://dom.uz/catalog/detail/14451
# https://dom.uz/catalog/detail/14452
# https://dom.uz/catalog/detail/14453
# https://dom.uz/catalog/detail/14454
# https://dom.uz/catalog/detail/14455
# https://dom.uz/catalog/detail/14456
# https://dom.uz/catalog/detail/14457
# https://dom.uz/catalog/detail/14458
# https://dom.uz/catalog/detail/14459
# https://dom.uz/catalog/detail/14460
# https://dom.uz/catalog/detail/14461
# https://dom.uz/catalog/detail/14462
# https://dom.uz/catalog/detail/14463
# https://dom.uz/catalog/detail/14464
# https://dom.uz/catalog/detail/14465
# https://dom.uz/catalog/detail/14466
# https://dom.uz/catalog/detail/14467
# https://dom.uz/catalog/detail/14468
# https://dom.uz/catalog/detail/14469
# https://dom.uz/catalog/detail/14470
# https://dom.uz/catalog/detail/14471
# https://dom.uz/catalog/detail/14472
# https://dom.uz/catalog/detail/14473
# https://dom.uz/catalog/detail/14474
# https://dom.uz/catalog/detail/14475
# https://dom.uz/catalog/detail/14476
# https://dom.uz/catalog/detail/14477
# https://dom.uz/catalog/detail/14478
# https://dom.uz/catalog/detail/14479
# https://dom.uz/catalog/detail/14480
# https://dom.uz/catalog/detail/14481
# https://dom.uz/catalog/detail/14482
# https://dom.uz/catalog/detail/14483
# https://dom.uz/catalog/detail/14484
# https://dom.uz/catalog/detail/14485
# https://dom.uz/catalog/detail/14486
# https://dom.uz/catalog/detail/14487
# https://dom.uz/catalog/detail/14488
# https://dom.uz/catalog/detail/14489
# https://dom.uz/catalog/detail/14490
# https://dom.uz/catalog/detail/14491
# https://dom.uz/catalog/detail/14492
# https://dom.uz/catalog/detail/14493
# https://dom.uz/catalog/detail/14494
# https://dom.uz/catalog/detail/14495
# https://dom.uz/catalog/detail/14496
# https://dom.uz/catalog/detail/14497
# https://dom.uz/catalog/detail/14498
# https://dom.uz/catalog/detail/14499
# https://dom.uz/catalog/detail/14500

# %%
final_df = final_df.rename(columns={'Массив, улица': 'Адрес', 'Вид материала': 'Материал'})
final_df['Площадь'] = final_df['Общая площадь, м2'].fillna(final_df['Площадь дома'])
final_df['Цена'] = pd.to_numeric(final_df['Цена'].str.replace(' ', ''), errors='coerce')
final_df['Количество комнат'] = pd.to_numeric(final_df['Количество комнат'].str.extract('(\\d+)', expand=False), errors='coerce')
final_df[['Долгота', 'Широта']] = final_df[['Долгота', 'Широта']].apply(pd.to_numeric, errors='coerce')

numeric_columns = ['Этаж квартиры', 'Этажность дома', 'Площадь', 'Количество соток']
final_df[numeric_columns] = final_df[numeric_columns].apply(pd.to_numeric, errors='coerce')
final_df = final_df.drop(['Площадь дома', 'Общая площадь, м2'],  axis=1)
final_df.columns
# Out:
# Index(['Название', 'Дата', 'Местоположение', 'Район', 'Адрес',
#        'Тип недвижимости', 'Количество комнат', 'Количество соток', 'Материал',
#        'Санузел', 'Состояние', 'Валюта', 'Цена', 'Долгота', 'Широта',
#        'Этаж квартиры', 'Этажность дома', 'Планировка', 'Постройки',
#        'Площадь'],
#       dtype='object')

# %%
final_df['Дата публикации'] = pd.to_datetime(final_df['Дата'], format='%Y-%m-%d').dt.strftime('%d.%m.%Y')

# %%
column_name_mapping = {
    "Название": "Тип",
    "Тип жилья": "Тип постройки",
    "Тип строения": "Материал",
    "Этажность дома": "Этажность",
    "Общая площадь": "Площадь",
}

# Rename the columns
final_df.rename(columns=column_name_mapping, inplace=True)

# %%
columns_to_check = ["Источник", "Название", "Тип","Санузел", "Тип постройки", "Материал", "Широта", 
                    "Долгота", "Район", "Этаж", "Этажность", "Ремонт", "Площадь", 
                    "Количество комнат", "Дата публикации", "Валюта", "Цена", "Дата создания"]

# Create a new DataFrame with the specified columns
new_df = pd.DataFrame(columns=columns_to_check)

# Check if columns exist in final_df and create them with None values if not
for column in columns_to_check:
    if column not in final_df.columns:
        final_df[column] = None
        new_df[column] = None
    else:
        new_df[column] = final_df[column]

new_df["Источник"] = 'Dom_uz'
new_df["Район"] = ''
new_df["Дата создания"] = datetime.now().strftime("%d.%m.%Y")
new_df[columns_to_check]
new_df.head()
# Out:
#   Источник Название                              Тип      Санузел  \
# 0   Dom_uz      NaN           Частный дом на продажу     Вне дома
# 1   Dom_uz      NaN  Квартира во вторичке на продажу  Совмещенный
# 2   Dom_uz      NaN           Частный дом на продажу  Совмещенный
# 3   Dom_uz      NaN  Квартира во вторичке на продажу   Раздельный
# 4   Dom_uz      NaN  Квартира во вторичке на продажу   Раздельный
#
#   Тип постройки Материал     Широта    Долгота Район  Этаж  Этажность Ремонт  \
# 0          None   Кирпич  41.311144  69.279728        None        NaN   None
# 1          None   Кирпич  41.311144  69.279728        None        4.0   None
# 2          None   Кирпич  41.291467  69.248142        None        NaN   None
# 3          None   Панель  41.194755  69.208943        None        9.0   None
# 4          None   Панель  41.262460  69.198704        None        9.0   None
#
#    Площадь  Количество комнат Дата публикации Валюта   Цена Дата создания
# 0    149.0                5.0      08.09.2023    USD  35000    02.06.2024
# 1     83.0                4.0      08.09.2023    USD  80000    02.06.2024
# 2     71.0                3.0      16.09.2023    USD  39900    02.06.2024
# 3     89.0                4.0      23.09.2023    USD  75000    02.06.2024
# 4     89.0                3.0      23.09.2023    USD  72000    02.06.2024

# %%
# Specify columns to check for duplicates
columns_to_check_dup = ["Источник", "Название", "Тип", "Санузел", "Тип постройки", "Материал", 
                    "Широта", "Долгота", "Район", "Этаж", "Этажность", "Ремонт", "Площадь", 
                    "Количество комнат", "Дата публикации", "Валюта", "Цена"]

# Count the number of rows before removing duplicates
rows_before = new_df.shape[0]

# Remove duplicates based on specified columns
df_no_duplicates = new_df.drop_duplicates(subset=columns_to_check_dup, keep=False)

# Count the number of rows after removing duplicates
rows_after = df_no_duplicates.shape[0]

# Calculate the number of rows deleted
rows_deleted = rows_before - rows_after

print(f"\nNumber of rows deleted: {rows_deleted}")
# Out:
# Number of rows deleted: 0

# %%
import pandas as pd
import os

# Assuming x is your variable and data is the data you want to store
name_of_file = "Dom_uz"
df = pd.DataFrame(new_df)

# Set the path to the Excels folder (assuming it is a sibling of the Notebooks folder)
excels_folder_path = os.path.join(os.path.dirname(os.getcwd()), "Excels")

# Check if the folder exists, if not, create it
if not os.path.exists(excels_folder_path):
    os.makedirs(excels_folder_path)

# Create a folder with the name_of_file only if it doesn't exist
file_folder_path = os.path.join(excels_folder_path, name_of_file)

if not os.path.exists(file_folder_path):
    os.makedirs(file_folder_path)

excel_file_name = os.path.join(file_folder_path, f"{name_of_file}.xlsx")

# Check if the file already exists
if os.path.exists(excel_file_name):
    # Read the existing Excel file into a DataFrame
    existing_df = pd.read_excel(excel_file_name)

    # Append the new data to the existing DataFrame
    updated_df = pd.concat([existing_df, df], ignore_index=True)

    # Check for duplicates in all columns
    duplicates_mask = updated_df.duplicated(keep=False)

    # Print the number of duplicates
    num_duplicates = duplicates_mask.sum()
    print(f"Number of duplicates after adding new data: {num_duplicates}")

    # If duplicates exist, remove them
    if any(duplicates_mask):
        updated_df = updated_df[~duplicates_mask]

    # Write the updated DataFrame back to the Excel file
    updated_df.to_excel(excel_file_name, index=False)

    print(f"Data added to existing Excel file '{excel_file_name}' after removing duplicates.")
else:
    # If the file doesn't exist, create a new Excel file with the data
    df.to_excel(excel_file_name, index=False)
    print(f"Excel file '{excel_file_name}' created with new data.")
# Out:
# Excel file '/Users/didi/Desktop/data_scrapping/Data Scrapping/Code/Excels/Dom_uz/Dom_uz.xlsx' created with new data.
